# %%
"""
Tutor MSAHIN
You can reach me on youtube, twitter, linkedin, medium and github with my @datasciengine username.
"""

# %% [markdown]
# # Görüntü İşleme

# %% [markdown]
# Görüntü İşleme, görüntüyü dijital form haline getirmek ve bazı işlemleri gerçekleştirmek için geliştirilmiş, spesifik görüntü elde etmek veya ondan bazı yararlı bilgiler çıkarmak için kullanılan bir yöntemdir.

# %% [markdown]
# Görüntü işleme bazı amaçlar
#
# 1. Görselleştirme – Görünmesi zor nesneleri gözlemleme
# 2. Görüntü keskinleştirme ve restorasyon – Gürültülü görüntüleri iyileştirme
# 3. Görüntü alımı – İlgi çekici ve yüksek çözünürlüklü görüntü arama
# 4. Desen Tanıma – Bir görüntüdeki çeşitli nesneleri tanımlama.
# 5. Görüntü Tanıma – Bir görüntüdeki nesneleri ayırt etme.
# ...

# %% [markdown]
# # Bilgisayarlı Görü (Computer Vision)

# %% [markdown]
# Computer Vision yani bilgisayar görüşü, bilgisayarların insanlar gibi gördükleri objeleri tanımlayabilmesine ve işleyebilmesine yarayan teknolojilerle ilgilenen bilgisayar bilimi alanıdır. Görüntüyü edinmek, işlemek, analiz etmek, anlamak, resimlerden sayısal veriler çıkarmak ve bunların sonucunda karar vermek konularını kapsar. Söz konusu görüntü, fotoğraf, video, aynı noktaya bakan birden çok kameradan alınan videolar, 3D tarayıcı ile edinilen görüntüler ya da ultrason cihazı gibi tıbbi görüntüleme cihazlarının çıktıları formunda olabilir.

# %% [markdown]
# ## Görüntü Bilgisayar için Nedir?

# %% [markdown]
# Bir matristir.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ne kadar siyah, ne kadar beyaz?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2^8 = 256

# %% [markdown]
# ## Peki Ya Renkli?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install opencv-python

# %%
import cv2 as cv

# %%
img = cv.imread('../VisualMaterials/Photos/people_2.jpg')

# %%
img.shape
# Out:
# (828, 640, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv.imshow('People', img)
cv.waitKey(0)
cv.destroyAllWindows()
